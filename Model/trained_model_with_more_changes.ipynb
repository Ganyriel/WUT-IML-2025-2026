# %%
import os
import pandas as pd

print("=" * 70)
print("GENERATING MANIFEST.CSV")
print("=" * 70)

# Data path
base_path = r'../data_recordings'

print(f"\n Base path: {base_path}")

rows = []

print("\n Processing ACCEPTED...")
accepted_folder = os.path.join(base_path, 'accepted')
if os.path.exists(accepted_folder):
    for speaker_folder in os.listdir(accepted_folder):
        speaker_path = os.path.join(accepted_folder, speaker_folder)
        if os.path.isdir(speaker_path):
            file_count = 0
            for file in os.listdir(speaker_path):
                if file.endswith(('.wav', '.mp3', '.flac')):
                    relative_path = os.path.join('accepted', speaker_folder, file)
                    rows.append({
                        'speaker_id': speaker_folder,
                        'path': relative_path,
                        'label': 1  # 1 = ACCEPTED
                    })
                    file_count += 1
            print(f"{speaker_folder}: {file_count} files")
else:
    print(f"Not found: {accepted_folder}")

print("\nProcessing REJECTED...")
rejected_folder = os.path.join(base_path, 'rejected')
if os.path.exists(rejected_folder):
    for speaker_folder in os.listdir(rejected_folder):
        speaker_path = os.path.join(rejected_folder, speaker_folder)
        if os.path.isdir(speaker_path):
            file_count = 0
            for file in os.listdir(speaker_path):
                if file.endswith(('.wav', '.mp3', '.flac')):
                    relative_path = os.path.join('rejected', speaker_folder, file)
                    rows.append({
                        'speaker_id': speaker_folder,
                        'path': relative_path,
                        'label': 0  # 0 = REJECTED
                    })
                    file_count += 1
            print(f"  {speaker_folder}: {file_count} files")
else:
    print(f" Not found: {rejected_folder}")

df = pd.DataFrame(rows)
manifest_file = os.path.join(base_path, 'manifest.csv')
df.to_csv(manifest_file, index=False)

print("\n" + "=" * 70)
print("MANIFEST GENERATED SUCCESFULLY")
print("=" * 70)
print(f"\nArchive: {manifest_file}")
print(f"Total archives: {len(df)}")
print(f"  • Accepted (label=1): {sum(df['label'] == 1)}")
print(f"  • Rejected (label=0): {sum(df['label'] == 0)}")
print(f"\nFirst 5 rows:")
print(df.head())
print(f"\nColumns: {df.columns.tolist()}")
# Out:
# ======================================================================
# GENERATING MANIFEST.CSV
# ======================================================================
#
#  Base path: ../data_recordings
#
#  Processing ACCEPTED...
# p001: 718 files
# p239: 900 files
# p243: 900 files
# p259: 901 files
# p268: 901 files
# p270: 900 files
#
# Processing REJECTED...
#   p226: 302 files
#   p227: 300 files
#   p228: 300 files
#   p230: 301 files
#   p231: 300 files
#   p232: 300 files
#   p233: 301 files
#   p236: 300 files
#   p244: 300 files
#   p250: 300 files
#   p254: 300 files
#   p256: 300 files
#   p257: 300 files
#   p258: 300 files
#   p267: 300 files
#   p269: 300 files
#   p273: 300 files
#   p274: 300 files
#   p276: 300 files
#   p277: 301 files
#
# ======================================================================
# MANIFEST GENERATED SUCCESFULLY
# ======================================================================
#
# Archive: ../data_recordings\manifest.csv
# Total archives: 11225
#   • Accepted (label=1): 5220
#   • Rejected (label=0): 6005
#
# First 5 rows:
#   speaker_id                            path  label
# 0       p001  accepted\p001\p001_001_000.wav      1
# 1       p001  accepted\p001\p001_001_001.wav      1
# 2       p001  accepted\p001\p001_001_002.wav      1
# 3       p001  accepted\p001\p001_002_000.wav      1
# 4       p001  accepted\p001\p001_002_001.wav      1
#
# Columns: ['speaker_id', 'path', 'label']

# %%
import numpy as np
import pandas as pd
import librosa
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split   # kept, though no longer used
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import os
import warnings
warnings.filterwarnings('ignore')

print("=" * 70)
print("SPEAKER VERIFICATION - CNN WITH MEL-SPECTROGRAMS")
print("=" * 70)


# Initialization of paths
base_path = r'../data_recordings'
manifest_path = os.path.join(base_path, 'manifest.csv')


MAX_SAMPLES = None # TODO what's this?

# Activating dropout
dropout = False
dropout_low = False

# ### Ratios for 3-way split
TRAIN_RATIO = 0.7
VAL_RATIO = 0.15
TEST_RATIO = 0.15
RANDOM_STATE = 42 # TODO what's this?




print(f"\nConfiguration:")
print(f"  Base path: {base_path}")
print(f"  Manifest: {manifest_path}")
print(f"  Max samples: {MAX_SAMPLES if MAX_SAMPLES else 'All'}")
print(f"  Split ratios (train/val/test): {TRAIN_RATIO}/{VAL_RATIO}/{TEST_RATIO}")

print("\n" + "=" * 70)
print("VERIFYING FILES AND PATHS")
print("=" * 70)

# Checking base folder and manifest
if not os.path.exists(base_path):
    raise FileNotFoundError(f"Base folder not found: {base_path}")
print("Base folder found")

if not os.path.exists(manifest_path):
    print("\nPlease run first: python run_pipeline_to_get_data.py")
    raise FileNotFoundError("manifest.csv not found")
print("Manifest found")




print("\n" + "=" * 70)
print("STEP 1: LOADING DATA FROM MANIFEST.CSV")
print("=" * 70)

df = pd.read_csv(manifest_path)
print(f"\nTotal entries: {len(df)}")

if MAX_SAMPLES:
    df = df.head(MAX_SAMPLES)

print(f"\nFirst 5 rows:")
print(df.head())

if 'path' not in df.columns or 'label' not in df.columns:
    raise ValueError("Incorrect manifest format")

print(f"\nClass distribution:")
print(f"  Accepted: {sum(df['label'] == 1)}")
print(f"  Rejected: {sum(df['label'] == 0)}")

# ### Extract speaker ID from the path
# Assumes something like: accepted/p001/file.wav  -> speaker 'p001'
df['speaker'] = df['path'].apply(lambda p: os.path.basename(os.path.dirname(p)))

print("\nNumber of unique speakers:", df['speaker'].nunique())
print("Sample speakers:", df['speaker'].unique()[:10])

def load_audio_file(file_path, base_folder, sr=22050, max_duration=3):
    full_path = os.path.join(base_folder, file_path)
    try:
        y, _ = librosa.load(full_path, sr=sr, duration=max_duration)
        y = y / (np.max(np.abs(y)) + 1e-6)
        y, _ = librosa.effects.trim(y, top_db=20)
        
        target_length = sr * max_duration
        if len(y) < target_length:
            y = np.pad(y, (0, target_length - len(y)))
        else:
            y = y[:target_length]
        return y
    except:
        return None

print("\n" + "=" * 70)
print("STEP 2: LOADING AUDIO FILES")
print("=" * 70)

audio_data = []
labels = []
speakers = []   # keep track of speaker for each loaded sample
failed = 0

for idx, row in df.iterrows():
    audio = load_audio_file(row['path'], base_path)
    if audio is not None:
        audio_data.append(audio)
        labels.append(row['label'])
        speakers.append(row['speaker'])
    else:
        failed += 1
    
    if (idx + 1) % 50 == 0:
        print(f"  Processed {idx + 1}/{len(df)} files...")

print(f"\nLoading completed: {len(audio_data)} files")
if failed > 0:
    print(f"Failed: {failed}")

if len(audio_data) == 0:
    raise ValueError("No data to train")



print("\n" + "=" * 70)
print("STEP 3: GENERATING MEL-SPECTROGRAMS")
print("=" * 70)

def audio_to_spectrogram(y, sr=22050, n_mels=128):
    # Function for creating spectrograms from audio files
    mel_spec = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels, fmax=8000)
    mel_spec_db = librosa.power_to_db(mel_spec, ref=np.max)
    return mel_spec_db[..., np.newaxis]

spectrograms = []
for i, audio in enumerate(audio_data):
    spectrograms.append(audio_to_spectrogram(audio))
    if (i + 1) % 50 == 0:
        print(f"  Processed {i + 1}/{len(audio_data)} spectrograms...")

spectrograms = np.array(spectrograms)
labels = np.array(labels)
speakers = np.array(speakers)

print(f"\nSpectrograms shape: {spectrograms.shape}")

def _get_recording_group_key(path, speaker):
    """
    Given a relative path like 'accepted/p226/p226_003_000.wav',
    return a deterministic group key.

    For most speakers: group by (speaker, original_recording_id) where
    original_recording_id is the middle number in 'p226_003_000'.

    For accepted/p001: treat each file as its own group (no special grouping).
    """
    norm_path = path.replace("\\", "/")
    basename = os.path.basename(norm_path)
    stem, _ = os.path.splitext(basename)
    parts = stem.split("_")

    # Special case: manual recordings
    if "/accepted/" in norm_path and speaker == "p001":
        return f"{speaker}|{stem}"

    # Typical auto-split pattern: pXXX_###_###
    if len(parts) >= 3 and parts[0] == speaker and parts[1].isdigit() and parts[2].isdigit():
        # use the middle number as "original recording" id
        original_id = parts[1]               
        return f"{speaker}|{original_id}"



def split_by_speaker_and_recording(
    X, y, speakers,
    train_ratio=0.7, val_ratio=0.15, test_ratio=0.15
):
    """
    3-way split:
      - per speaker
      - keeping all segments from the same original recording together
      - except for manual recordings TODO why?
    """

    # Checking if data is loaded succesfully
    if not (len(X) == len(y) == len(speakers)):
        raise ValueError("X, y and speakers must have the same length")

    # We rely on the fact that each loaded sample corresponds to the same row in df.
    # If some files failed to load, we stop rather than mis-align.
    if 'failed' in globals() and failed != 0:
        raise ValueError(
            "Splitting assumes all files loaded successfully (failed == 0). "
            "Got failed != 0; please adjust loading logic or splitting."
        )
    if len(df) != len(X):
        raise ValueError(
            f"Length mismatch between df ({len(df)}) and data ({len(X)}). "
            "Splitting by recording cannot be done safely."
        )

    # Build groups: (speaker, recording_group_key) -> list of sample indices
    groups_per_speaker = {} 
    for idx, spk in enumerate(speakers):
        path = df.loc[idx, "path"]
        group_key = _get_recording_group_key(path, spk)

        if spk not in groups_per_speaker:
            groups_per_speaker[spk] = {}
        if group_key not in groups_per_speaker[spk]:
            groups_per_speaker[spk][group_key] = []
        groups_per_speaker[spk][group_key].append(idx)

    train_idx, val_idx, test_idx = [], [], []

    for spk in sorted(groups_per_speaker.keys()):
        group_dict = groups_per_speaker[spk]
        grouped_items = sorted(group_dict.items(), key=lambda kv: kv[0])

        # Total samples for this speaker
        all_indices = [i for _, idxs in grouped_items for i in idxs]
        n_total = len(all_indices)

        target_train = int(round(train_ratio * n_total))
        target_val = int(round(val_ratio * n_total))
        n_train = n_val = 0

        for group_key, idxs in grouped_items:
            gsize = len(idxs)

            if n_train + gsize <= target_train:
                train_idx.extend(idxs)
                n_train += gsize
            elif n_val + gsize <= target_val:
                val_idx.extend(idxs)
                n_val += gsize
            else:
                test_idx.extend(idxs)

    train_idx = np.array(sorted(train_idx))
    val_idx = np.array(sorted(val_idx))
    test_idx = np.array(sorted(test_idx))

    return (
        X[train_idx], X[val_idx], X[test_idx],
        y[train_idx], y[val_idx], y[test_idx]
    )


X_train, X_val, X_test, y_train, y_val, y_test = split_by_speaker_and_recording(
    spectrograms,
    labels,
    speakers,
    train_ratio=TRAIN_RATIO,
    val_ratio=VAL_RATIO,
    test_ratio=TEST_RATIO
)

print(f"\nFinal split sizes:")
print(f"  Train:      {X_train.shape[0]}")
print(f"  Validation: {X_val.shape[0]}")
print(f"  Test:       {X_test.shape[0]}")
# Out:
# ======================================================================
# SPEAKER VERIFICATION - CNN WITH MEL-SPECTROGRAMS
# ======================================================================
#
# Configuration:
#   Base path: ../data_recordings
#   Manifest: ../data_recordings\manifest.csv
#   Max samples: All
#   Split ratios (train/val/test): 0.7/0.15/0.15
#
# ======================================================================
# VERIFYING FILES AND PATHS
# ======================================================================
# Base folder found
# Manifest found
#
# ======================================================================
# STEP 1: LOADING DATA FROM MANIFEST.CSV
# ======================================================================
#
# Total entries: 11225
#
# First 5 rows:
#   speaker_id                            path  label
# 0       p001  accepted\p001\p001_001_000.wav      1
# 1       p001  accepted\p001\p001_001_001.wav      1
# 2       p001  accepted\p001\p001_001_002.wav      1
# 3       p001  accepted\p001\p001_002_000.wav      1
# 4       p001  accepted\p001\p001_002_001.wav      1
#
# Class distribution:
#   Accepted: 5220
#   Rejected: 6005
#
# Number of unique speakers: 26
# Sample speakers: ['p001' 'p239' 'p243' 'p259' 'p268' 'p270' 'p226' 'p227' 'p228' 'p230']
#
# ======================================================================
# STEP 2: LOADING AUDIO FILES
# ======================================================================
#   Processed 50/11225 files...
#   Processed 100/11225 files...
#   Processed 150/11225 files...
#   Processed 200/11225 files...
#   Processed 250/11225 files...
#   Processed 300/11225 files...
#   Processed 350/11225 files...
#   Processed 400/11225 files...
#   Processed 450/11225 files...
#   Processed 500/11225 files...
#   Processed 550/11225 files...
#   Processed 600/11225 files...
#   Processed 650/11225 files...
#   Processed 700/11225 files...
#   Processed 750/11225 files...
#   Processed 800/11225 files...
#   Processed 850/11225 files...
#   Processed 900/11225 files...
#   Processed 950/11225 files...
#   Processed 1000/11225 files...
#   Processed 1050/11225 files...
#   Processed 1100/11225 files...
#   Processed 1150/11225 files...
#   Processed 1200/11225 files...
#   Processed 1250/11225 files...
#   Processed 1300/11225 files...
#   Processed 1350/11225 files...
#   Processed 1400/11225 files...
#   Processed 1450/11225 files...
#   Processed 1500/11225 files...
#   Processed 1550/11225 files...
#   Processed 1600/11225 files...
#   Processed 1650/11225 files...
#   Processed 1700/11225 files...
#   Processed 1750/11225 files...
#   Processed 1800/11225 files...
#   Processed 1850/11225 files...
#   Processed 1900/11225 files...
#   Processed 1950/11225 files...
#   Processed 2000/11225 files...
#   Processed 2050/11225 files...
#   Processed 2100/11225 files...
#   Processed 2150/11225 files...
#   Processed 2200/11225 files...
#   Processed 2250/11225 files...
#   Processed 2300/11225 files...
#   Processed 2350/11225 files...
#   Processed 2400/11225 files...
#   Processed 2450/11225 files...
#   Processed 2500/11225 files...
#   Processed 2550/11225 files...
#   Processed 2600/11225 files...
#   Processed 2650/11225 files...
#   Processed 2700/11225 files...
#   Processed 2750/11225 files...
#   Processed 2800/11225 files...
#   Processed 2850/11225 files...
#   Processed 2900/11225 files...
#   Processed 2950/11225 files...
#   Processed 3000/11225 files...
#   Processed 3050/11225 files...
#   Processed 3100/11225 files...
#   Processed 3150/11225 files...
#   Processed 3200/11225 files...
#   Processed 3250/11225 files...
#   Processed 3300/11225 files...
#   Processed 3350/11225 files...
#   Processed 3400/11225 files...
#   Processed 3450/11225 files...
#   Processed 3500/11225 files...
#   Processed 3550/11225 files...
#   Processed 3600/11225 files...
#   Processed 3650/11225 files...
#   Processed 3700/11225 files...
#   Processed 3750/11225 files...
#   Processed 3800/11225 files...
#   Processed 3850/11225 files...
#   Processed 3900/11225 files...
#   Processed 3950/11225 files...
#   Processed 4000/11225 files...
#   Processed 4050/11225 files...
#   Processed 4100/11225 files...
#   Processed 4150/11225 files...
#   Processed 4200/11225 files...
#   Processed 4250/11225 files...
#   Processed 4300/11225 files...
#   Processed 4350/11225 files...
#   Processed 4400/11225 files...
#   Processed 4450/11225 files...
#   Processed 4500/11225 files...
#   Processed 4550/11225 files...
#   Processed 4600/11225 files...
#   Processed 4650/11225 files...
#   Processed 4700/11225 files...
#   Processed 4750/11225 files...
#   Processed 4800/11225 files...
#   Processed 4850/11225 files...
#   Processed 4900/11225 files...
#   Processed 4950/11225 files...
#   Processed 5000/11225 files...
#   Processed 5050/11225 files...
#   Processed 5100/11225 files...
#   Processed 5150/11225 files...
#   Processed 5200/11225 files...
#   Processed 5250/11225 files...
#   Processed 5300/11225 files...
#   Processed 5350/11225 files...
#   Processed 5400/11225 files...
#   Processed 5450/11225 files...
#   Processed 5500/11225 files...
#   Processed 5550/11225 files...
#   Processed 5600/11225 files...
#   Processed 5650/11225 files...
#   Processed 5700/11225 files...
#   Processed 5750/11225 files...
#   Processed 5800/11225 files...
#   Processed 5850/11225 files...
#   Processed 5900/11225 files...
#   Processed 5950/11225 files...
#   Processed 6000/11225 files...
#   Processed 6050/11225 files...
#   Processed 6100/11225 files...
#   Processed 6150/11225 files...
#   Processed 6200/11225 files...
#   Processed 6250/11225 files...
#   Processed 6300/11225 files...
#   Processed 6350/11225 files...
#   Processed 6400/11225 files...
#   Processed 6450/11225 files...
#   Processed 6500/11225 files...
#   Processed 6550/11225 files...
#   Processed 6600/11225 files...
#   Processed 6650/11225 files...
#   Processed 6700/11225 files...
#   Processed 6750/11225 files...
#   Processed 6800/11225 files...
#   Processed 6850/11225 files...
#   Processed 6900/11225 files...
#   Processed 6950/11225 files...
#   Processed 7000/11225 files...
#   Processed 7050/11225 files...
#   Processed 7100/11225 files...
#   Processed 7150/11225 files...
#   Processed 7200/11225 files...
#   Processed 7250/11225 files...
#   Processed 7300/11225 files...
#   Processed 7350/11225 files...
#   Processed 7400/11225 files...
#   Processed 7450/11225 files...
#   Processed 7500/11225 files...
#   Processed 7550/11225 files...
#   Processed 7600/11225 files...
#   Processed 7650/11225 files...
#   Processed 7700/11225 files...
#   Processed 7750/11225 files...
#   Processed 7800/11225 files...
#   Processed 7850/11225 files...
#   Processed 7900/11225 files...
#   Processed 7950/11225 files...
#   Processed 8000/11225 files...
#   Processed 8050/11225 files...
#   Processed 8100/11225 files...
#   Processed 8150/11225 files...
#   Processed 8200/11225 files...
#   Processed 8250/11225 files...
#   Processed 8300/11225 files...
#   Processed 8350/11225 files...
#   Processed 8400/11225 files...
#   Processed 8450/11225 files...
#   Processed 8500/11225 files...
#   Processed 8550/11225 files...
#   Processed 8600/11225 files...
#   Processed 8650/11225 files...
#   Processed 8700/11225 files...
#   Processed 8750/11225 files...
#   Processed 8800/11225 files...
#   Processed 8850/11225 files...
#   Processed 8900/11225 files...
#   Processed 8950/11225 files...
#   Processed 9000/11225 files...
#   Processed 9050/11225 files...
#   Processed 9100/11225 files...
#   Processed 9150/11225 files...
#   Processed 9200/11225 files...
#   Processed 9250/11225 files...
#   Processed 9300/11225 files...
#   Processed 9350/11225 files...
#   Processed 9400/11225 files...
#   Processed 9450/11225 files...
#   Processed 9500/11225 files...
#   Processed 9550/11225 files...
#   Processed 9600/11225 files...
#   Processed 9650/11225 files...
#   Processed 9700/11225 files...
#   Processed 9750/11225 files...
#   Processed 9800/11225 files...
#   Processed 9850/11225 files...
#   Processed 9900/11225 files...
#   Processed 9950/11225 files...
#   Processed 10000/11225 files...
#   Processed 10050/11225 files...
#   Processed 10100/11225 files...
#   Processed 10150/11225 files...
#   Processed 10200/11225 files...
#   Processed 10250/11225 files...
#   Processed 10300/11225 files...
#   Processed 10350/11225 files...
#   Processed 10400/11225 files...
#   Processed 10450/11225 files...
#   Processed 10500/11225 files...
#   Processed 10550/11225 files...
#   Processed 10600/11225 files...
#   Processed 10650/11225 files...
#   Processed 10700/11225 files...
#   Processed 10750/11225 files...
#   Processed 10800/11225 files...
#   Processed 10850/11225 files...
#   Processed 10900/11225 files...
#   Processed 10950/11225 files...
#   Processed 11000/11225 files...
#   Processed 11050/11225 files...
#   Processed 11100/11225 files...
#   Processed 11150/11225 files...
#   Processed 11200/11225 files...
#
# Loading completed: 11225 files
#
# ======================================================================
# STEP 3: GENERATING MEL-SPECTROGRAMS
# ======================================================================
#   Processed 50/11225 spectrograms...
#   Processed 100/11225 spectrograms...
#   Processed 150/11225 spectrograms...
#   Processed 200/11225 spectrograms...
#   Processed 250/11225 spectrograms...
#   Processed 300/11225 spectrograms...
#   Processed 350/11225 spectrograms...
#   Processed 400/11225 spectrograms...
#   Processed 450/11225 spectrograms...
#   Processed 500/11225 spectrograms...
#   Processed 550/11225 spectrograms...
#   Processed 600/11225 spectrograms...
#   Processed 650/11225 spectrograms...
#   Processed 700/11225 spectrograms...
#   Processed 750/11225 spectrograms...
#   Processed 800/11225 spectrograms...
#   Processed 850/11225 spectrograms...
#   Processed 900/11225 spectrograms...
#   Processed 950/11225 spectrograms...
#   Processed 1000/11225 spectrograms...
#   Processed 1050/11225 spectrograms...
#   Processed 1100/11225 spectrograms...
#   Processed 1150/11225 spectrograms...
#   Processed 1200/11225 spectrograms...
#   Processed 1250/11225 spectrograms...
#   Processed 1300/11225 spectrograms...
#   Processed 1350/11225 spectrograms...
#   Processed 1400/11225 spectrograms...
#   Processed 1450/11225 spectrograms...
#   Processed 1500/11225 spectrograms...
#   Processed 1550/11225 spectrograms...
#   Processed 1600/11225 spectrograms...
#   Processed 1650/11225 spectrograms...
#   Processed 1700/11225 spectrograms...
#   Processed 1750/11225 spectrograms...
#   Processed 1800/11225 spectrograms...
#   Processed 1850/11225 spectrograms...
#   Processed 1900/11225 spectrograms...
#   Processed 1950/11225 spectrograms...
#   Processed 2000/11225 spectrograms...
#   Processed 2050/11225 spectrograms...
#   Processed 2100/11225 spectrograms...
#   Processed 2150/11225 spectrograms...
#   Processed 2200/11225 spectrograms...
#   Processed 2250/11225 spectrograms...
#   Processed 2300/11225 spectrograms...
#   Processed 2350/11225 spectrograms...
#   Processed 2400/11225 spectrograms...
#   Processed 2450/11225 spectrograms...
#   Processed 2500/11225 spectrograms...
#   Processed 2550/11225 spectrograms...
#   Processed 2600/11225 spectrograms...
#   Processed 2650/11225 spectrograms...
#   Processed 2700/11225 spectrograms...
#   Processed 2750/11225 spectrograms...
#   Processed 2800/11225 spectrograms...
#   Processed 2850/11225 spectrograms...
#   Processed 2900/11225 spectrograms...
#   Processed 2950/11225 spectrograms...
#   Processed 3000/11225 spectrograms...
#   Processed 3050/11225 spectrograms...
#   Processed 3100/11225 spectrograms...
#   Processed 3150/11225 spectrograms...
#   Processed 3200/11225 spectrograms...
#   Processed 3250/11225 spectrograms...
#   Processed 3300/11225 spectrograms...
#   Processed 3350/11225 spectrograms...
#   Processed 3400/11225 spectrograms...
#   Processed 3450/11225 spectrograms...
#   Processed 3500/11225 spectrograms...
#   Processed 3550/11225 spectrograms...
#   Processed 3600/11225 spectrograms...
#   Processed 3650/11225 spectrograms...
#   Processed 3700/11225 spectrograms...
#   Processed 3750/11225 spectrograms...
#   Processed 3800/11225 spectrograms...
#   Processed 3850/11225 spectrograms...
#   Processed 3900/11225 spectrograms...
#   Processed 3950/11225 spectrograms...
#   Processed 4000/11225 spectrograms...
#   Processed 4050/11225 spectrograms...
#   Processed 4100/11225 spectrograms...
#   Processed 4150/11225 spectrograms...
#   Processed 4200/11225 spectrograms...
#   Processed 4250/11225 spectrograms...
#   Processed 4300/11225 spectrograms...
#   Processed 4350/11225 spectrograms...
#   Processed 4400/11225 spectrograms...
#   Processed 4450/11225 spectrograms...
#   Processed 4500/11225 spectrograms...
#   Processed 4550/11225 spectrograms...
#   Processed 4600/11225 spectrograms...
#   Processed 4650/11225 spectrograms...
#   Processed 4700/11225 spectrograms...
#   Processed 4750/11225 spectrograms...
#   Processed 4800/11225 spectrograms...
#   Processed 4850/11225 spectrograms...
#   Processed 4900/11225 spectrograms...
#   Processed 4950/11225 spectrograms...
#   Processed 5000/11225 spectrograms...
#   Processed 5050/11225 spectrograms...
#   Processed 5100/11225 spectrograms...
#   Processed 5150/11225 spectrograms...
#   Processed 5200/11225 spectrograms...
#   Processed 5250/11225 spectrograms...
#   Processed 5300/11225 spectrograms...
#   Processed 5350/11225 spectrograms...
#   Processed 5400/11225 spectrograms...
#   Processed 5450/11225 spectrograms...
#   Processed 5500/11225 spectrograms...
#   Processed 5550/11225 spectrograms...
#   Processed 5600/11225 spectrograms...
#   Processed 5650/11225 spectrograms...
#   Processed 5700/11225 spectrograms...
#   Processed 5750/11225 spectrograms...
#   Processed 5800/11225 spectrograms...
#   Processed 5850/11225 spectrograms...
#   Processed 5900/11225 spectrograms...
#   Processed 5950/11225 spectrograms...
#   Processed 6000/11225 spectrograms...
#   Processed 6050/11225 spectrograms...
#   Processed 6100/11225 spectrograms...
#   Processed 6150/11225 spectrograms...
#   Processed 6200/11225 spectrograms...
#   Processed 6250/11225 spectrograms...
#   Processed 6300/11225 spectrograms...
#   Processed 6350/11225 spectrograms...
#   Processed 6400/11225 spectrograms...
#   Processed 6450/11225 spectrograms...
#   Processed 6500/11225 spectrograms...
#   Processed 6550/11225 spectrograms...
#   Processed 6600/11225 spectrograms...
#   Processed 6650/11225 spectrograms...
#   Processed 6700/11225 spectrograms...
#   Processed 6750/11225 spectrograms...
#   Processed 6800/11225 spectrograms...
#   Processed 6850/11225 spectrograms...
#   Processed 6900/11225 spectrograms...
#   Processed 6950/11225 spectrograms...
#   Processed 7000/11225 spectrograms...
#   Processed 7050/11225 spectrograms...
#   Processed 7100/11225 spectrograms...
#   Processed 7150/11225 spectrograms...
#   Processed 7200/11225 spectrograms...
#   Processed 7250/11225 spectrograms...
#   Processed 7300/11225 spectrograms...
#   Processed 7350/11225 spectrograms...
#   Processed 7400/11225 spectrograms...
#   Processed 7450/11225 spectrograms...
#   Processed 7500/11225 spectrograms...
#   Processed 7550/11225 spectrograms...
#   Processed 7600/11225 spectrograms...
#   Processed 7650/11225 spectrograms...
#   Processed 7700/11225 spectrograms...
#   Processed 7750/11225 spectrograms...
#   Processed 7800/11225 spectrograms...
#   Processed 7850/11225 spectrograms...
#   Processed 7900/11225 spectrograms...
#   Processed 7950/11225 spectrograms...
#   Processed 8000/11225 spectrograms...
#   Processed 8050/11225 spectrograms...
#   Processed 8100/11225 spectrograms...
#   Processed 8150/11225 spectrograms...
#   Processed 8200/11225 spectrograms...
#   Processed 8250/11225 spectrograms...
#   Processed 8300/11225 spectrograms...
#   Processed 8350/11225 spectrograms...
#   Processed 8400/11225 spectrograms...
#   Processed 8450/11225 spectrograms...
#   Processed 8500/11225 spectrograms...
#   Processed 8550/11225 spectrograms...
#   Processed 8600/11225 spectrograms...
#   Processed 8650/11225 spectrograms...
#   Processed 8700/11225 spectrograms...
#   Processed 8750/11225 spectrograms...
#   Processed 8800/11225 spectrograms...
#   Processed 8850/11225 spectrograms...
#   Processed 8900/11225 spectrograms...
#   Processed 8950/11225 spectrograms...
#   Processed 9000/11225 spectrograms...
#   Processed 9050/11225 spectrograms...
#   Processed 9100/11225 spectrograms...
#   Processed 9150/11225 spectrograms...
#   Processed 9200/11225 spectrograms...
#   Processed 9250/11225 spectrograms...
#   Processed 9300/11225 spectrograms...
#   Processed 9350/11225 spectrograms...
#   Processed 9400/11225 spectrograms...
#   Processed 9450/11225 spectrograms...
#   Processed 9500/11225 spectrograms...
#   Processed 9550/11225 spectrograms...
#   Processed 9600/11225 spectrograms...
#   Processed 9650/11225 spectrograms...
#   Processed 9700/11225 spectrograms...
#   Processed 9750/11225 spectrograms...
#   Processed 9800/11225 spectrograms...
#   Processed 9850/11225 spectrograms...
#   Processed 9900/11225 spectrograms...
#   Processed 9950/11225 spectrograms...
#   Processed 10000/11225 spectrograms...
#   Processed 10050/11225 spectrograms...
#   Processed 10100/11225 spectrograms...
#   Processed 10150/11225 spectrograms...
#   Processed 10200/11225 spectrograms...
#   Processed 10250/11225 spectrograms...
#   Processed 10300/11225 spectrograms...
#   Processed 10350/11225 spectrograms...
#   Processed 10400/11225 spectrograms...
#   Processed 10450/11225 spectrograms...
#   Processed 10500/11225 spectrograms...
#   Processed 10550/11225 spectrograms...
#   Processed 10600/11225 spectrograms...
#   Processed 10650/11225 spectrograms...
#   Processed 10700/11225 spectrograms...
#   Processed 10750/11225 spectrograms...
#   Processed 10800/11225 spectrograms...
#   Processed 10850/11225 spectrograms...
#   Processed 10900/11225 spectrograms...
#   Processed 10950/11225 spectrograms...
#   Processed 11000/11225 spectrograms...
#   Processed 11050/11225 spectrograms...
#   Processed 11100/11225 spectrograms...
#   Processed 11150/11225 spectrograms...
#   Processed 11200/11225 spectrograms...
#
# Spectrograms shape: (11225, 128, 130, 1)
#
# Final split sizes:
#   Train:      7859
#   Validation: 1681
#   Test:       1685

# %%
print("\n" + "=" * 70)
print("STEP 4: BUILDING AND TRAINING CNN")
print("=" * 70)


norm_layer = layers.Normalization()
norm_layer.adapt(X_train)


# Building models

def build_cnn_model(input_shape, norm):
    # default model (without dropout or anything)
    return models.Sequential([
        layers.Input(shape=input_shape),
        norm,
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),   # before 32
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),  # before 64
        layers.MaxPooling2D((2, 2)),
        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),  # before 128
        layers.MaxPooling2D((2, 2)),
        layers.Flatten(),
        layers.Dense(256, activation='relu'),                           # before 128
        layers.Dense(1, activation='sigmoid')
    ])

#This already allows you to say that you have tested architectures with different layer depths and sizes.

'''
def build_cnn_model(input_shape, norm):
    # default model with batch normalization
    return models.Sequential([
        layers.Input(shape=input_shape),
        norm,

        layers.Conv2D(64, (3, 3), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(128, (3, 3), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(256, (3, 3), padding='same', use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.MaxPooling2D((2, 2)),

        layers.Flatten(),
        layers.Dense(256, use_bias=False),
        layers.BatchNormalization(),
        layers.Activation('relu'),
        layers.Dense(1, activation='sigmoid')
    ])
'''

def build_cnn_model_dropout(input_shape, norm):
    # model with dropout
    return models.Sequential([
        layers.Input(shape=input_shape),
        norm,
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.2),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.2),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.2),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid')
    ])

def build_cnn_model_dropout_low(input_shape, norm):
    # model with low dropout (for comparison)
    return models.Sequential([
        layers.Input(shape=input_shape),
        norm,
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.1),
        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.1),
        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.1),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.1),
        layers.Dense(1, activation='sigmoid')
    ])


# Checking which model to use
if (dropout):
    model = build_cnn_model_dropout(X_train.shape[1:], norm_layer)
elif(dropout_low):
    model = build_cnn_model_dropout_low(X_train.shape[1:], norm_layer)
else:
    model = build_cnn_model(X_train.shape[1:], norm_layer)

# Show model
model.summary()

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# If training is fast, we can stop early
# TODO check if values can be improved
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True, verbose=1
)
def lr_scheduler(epoch, lr):
    # mantiene el LR hasta la época 5 y luego lo reduce 10x
    if epoch < 5:
        return lr
    else:
        return lr * 0.1

lr_callback = tf.keras.callbacks.LearningRateScheduler(lr_scheduler, verbose=1)


history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val), 
    epochs=15,
    batch_size=16,
    callbacks=[early_stop, lr_callback],
    verbose=1
)

'''
This step helps the model learn faster at the beginning and then fine‑tune more 
carefully later by automatically reducing the learning rate during training, 
which can improve convergence stability and final accuracy. 
'''

print("\n" + "=" * 70)
print("STEP 5: EVALUATION AND RESULTS (ON TEST SET)")
print("=" * 70)


#Plotting
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'], label='Train', linewidth=2)
ax1.plot(history.history['val_accuracy'], label='Validation', linewidth=2)
ax1.set_title('Model Accuracy', fontsize=14, fontweight='bold')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True, alpha=0.3)

ax2.plot(history.history['loss'], label='Train', linewidth=2)
ax2.plot(history.history['val_loss'], label='Validation', linewidth=2)
ax2.set_title('Model Loss', fontsize=14, fontweight='bold')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig('training_history.png', dpi=150, bbox_inches='tight')
plt.show()

y_test_pred_prob = model.predict(X_test)
y_test_pred = (y_test_pred_prob > 0.5).astype(int).flatten()

test_accuracy = accuracy_score(y_test, y_test_pred)
print(f"\nTEST ACCURACY: {test_accuracy*100:.2f}%\n")
print(classification_report(y_test, y_test_pred, target_names=['Rejected', 'Accepted']))

cm = confusion_matrix(y_test, y_test_pred)

plt.figure(figsize=(8, 6))
plt.imshow(cm, interpolation='nearest', cmap='Blues')
plt.title('Confusion Matrix (Test Set)', fontsize=16, fontweight='bold')
plt.colorbar()

classes = ['Rejected', 'Accepted']
plt.xticks([0, 1], classes)
plt.yticks([0, 1], classes)

thresh = cm.max() / 2.
for i in range(2):
    for j in range(2):
        plt.text(j, i, format(cm[i, j], 'd'),
                 ha="center", va="center",
                 color="white" if cm[i, j] > thresh else "black",
                 fontsize=20, fontweight='bold')

plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig('confusion_matrix.png', dpi=150, bbox_inches='tight')
plt.show()

results_df = pd.DataFrame({
    'true_label': y_test,
    'predicted_label': y_test_pred,
    'confidence': y_test_pred_prob.flatten()
})
results_df.to_csv('test_results.csv', index=False)

# Saving model
model.save('speaker_verification_model.h5')


print("\n" + "=" * 70)
print("TRAINING COMPLETED SUCCESSFULLY!")
print("=" * 70)
print("\nGenerated files:")
print("  • training_history.png")
print("  • confusion_matrix.png")
print("  • test_results.csv")
print("  • speaker_verification_model.h5")
# Out:
# ======================================================================
# STEP 4: BUILDING AND TRAINING CNN
# ======================================================================
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)        │ (None, 128, 130, 1)         │               3 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 128, 130, 64)        │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 65, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 65, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 32, 32, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 16, 16, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 65536)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │      16,777,472 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │             257 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,147,396 (65.41 MB)
#  Trainable params: 17,147,393 (65.41 MB)
#  Non-trainable params: 3 (16.00 B)
# Epoch 1: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 1/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 117s 234ms/step - accuracy: 0.7253 - loss: 0.5171 - val_accuracy: 0.8465 - val_loss: 0.3418 - learning_rate: 0.0010
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 2/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 119s 241ms/step - accuracy: 0.8820 - loss: 0.2773 - val_accuracy: 0.8650 - val_loss: 0.3027 - learning_rate: 0.0010
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 3/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 121s 246ms/step - accuracy: 0.9188 - loss: 0.2006 - val_accuracy: 0.9084 - val_loss: 0.2164 - learning_rate: 0.0010
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 4/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 116s 235ms/step - accuracy: 0.9361 - loss: 0.1574 - val_accuracy: 0.9346 - val_loss: 0.1790 - learning_rate: 0.0010
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0010000000474974513.
# Epoch 5/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 111s 226ms/step - accuracy: 0.9567 - loss: 0.1092 - val_accuracy: 0.9411 - val_loss: 0.1467 - learning_rate: 0.0010
#
# Epoch 6: LearningRateScheduler setting learning rate to 0.00010000000474974513.
# Epoch 6/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 110s 224ms/step - accuracy: 0.9826 - loss: 0.0496 - val_accuracy: 0.9619 - val_loss: 0.1078 - learning_rate: 1.0000e-04
#
# Epoch 7: LearningRateScheduler setting learning rate to 1.0000000474974514e-05.
# Epoch 7/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 111s 226ms/step - accuracy: 0.9892 - loss: 0.0373 - val_accuracy: 0.9595 - val_loss: 0.1113 - learning_rate: 1.0000e-05
#
# Epoch 8: LearningRateScheduler setting learning rate to 1.0000000656873453e-06.
# Epoch 8/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 111s 225ms/step - accuracy: 0.9893 - loss: 0.0357 - val_accuracy: 0.9595 - val_loss: 0.1116 - learning_rate: 1.0000e-06
#
# Epoch 9: LearningRateScheduler setting learning rate to 1.0000001111620805e-07.
# Epoch 9/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 110s 224ms/step - accuracy: 0.9892 - loss: 0.0355 - val_accuracy: 0.9595 - val_loss: 0.1116 - learning_rate: 1.0000e-07
#
# Epoch 10: LearningRateScheduler setting learning rate to 1.000000082740371e-08.
# Epoch 10/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 145s 231ms/step - accuracy: 0.9892 - loss: 0.0355 - val_accuracy: 0.9595 - val_loss: 0.1116 - learning_rate: 1.0000e-08
#
# Epoch 11: LearningRateScheduler setting learning rate to 1.000000082740371e-09.
# Epoch 11/15
# 492/492 ━━━━━━━━━━━━━━━━━━━━ 112s 227ms/step - accuracy: 0.9892 - loss: 0.0355 - val_accuracy: 0.9595 - val_loss: 0.1116 - learning_rate: 1.0000e-09
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 6.
#
# ======================================================================
# STEP 5: EVALUATION AND RESULTS (ON TEST SET)
# ======================================================================
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 88ms/step
#
# TEST ACCURACY: 94.36%
#
#               precision    recall  f1-score   support
#
#     Rejected       0.97      0.93      0.95       902
#     Accepted       0.92      0.96      0.94       783
#
#     accuracy                           0.94      1685
#    macro avg       0.94      0.94      0.94      1685
# weighted avg       0.94      0.94      0.94      1685
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ======================================================================
# TRAINING COMPLETED SUCCESSFULLY!
# ======================================================================
#
# Generated files:
#   • training_history.png
#   • confusion_matrix.png
#   • test_results.csv
#   • speaker_verification_model.h5
